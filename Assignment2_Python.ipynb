# %%
import pandas as pd
import numpy as np
import Assignment2_classes as cl
import time
import gc
import psutil
import os

# %% [markdown]
# ## Git log

# %% [markdown]
# commit 053bb2847a85993dccaf9f6d82d5c8ad2f027470 (HEAD -> master)
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Tue Apr 23 18:56:01 2024 +0300
#
#     Adding final details and comments
#
# commit 2f04edc1fb8d967b3efc031d7184c5907b8c7a31
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Tue Apr 23 02:23:27 2024 +0300
#
#     Adding functions for stage 2 of assignment and analysis in jupyter notebook
#
# commit e654edba700904600c5607af29a54dad9084c505
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Wed Mar 27 13:40:50 2024 +0200
#
#     Updating Assignment2 Jupyter notebook demonstrating use of table statistics and repeated rows functions
#
# commit 1b6028df9136882e5f60b7d9af251fe1ac351b15
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Wed Mar 27 13:35:53 2024 +0200
#
#     Adding function of descriptive table statistics and function to find repeated rows for tha Data-cleaning class
#
# commit 2234f89e1c8699458e91b80ece4989a3b04bdfe6
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Wed Feb 28 18:27:31 2024 +0200
#
#     Adding Data_cleaning class and functions to remove rows and replace missing values
#
# commit 3f3c75c3ee614dc50cf2ce128361e1294d4fe0e0
# Author: Stelios Theocharous <st296@st-andrews.ac.uk>
# Date:   Wed Feb 28 00:56:57 2024 +0200
#
#     Juputer Notebook,Stage1-Initial Data Analysis/Plots

# %% [markdown]
# ## Task 1

# %%
path="P2data4105.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#      Level    T4    T3  T3adjusted  T4adjusted
# 0        5   8.1   2.1    2.008299    1.280579
# 1        5   8.7   NaN    2.056710         NaN
# 2       10   3.5   1.6    1.518294    1.169607
# 3       20   7.9   4.6    1.991632    1.663103
# 4       30   2.3   0.4    1.320006    0.736806
# ..     ...   ...   ...         ...         ...
# 494    150 -13.6  -4.5   -2.386966   -1.650964
# 495     60  17.2  29.2    2.581326    3.079363
# 496    400   2.7  14.7    1.392477    2.449660
# 497    150  29.4  27.6    3.086378    3.022060
# 498    200   6.5   3.8    1.866256    1.560491
#
# [499 rows x 5 columns]

# %%
df.describe()
# Out:
#             Level          T4          T3  T3adjusted  T4adjusted
# count  499.000000  489.000000  392.000000  493.000000  392.000000
# mean    35.861723   15.608233   13.295835    2.036462    1.905152
# std     64.513618   19.775264   16.441927    1.294579    1.247584
# min      5.000000  -44.400000  -38.400000   -3.541014   -3.373731
# 25%     10.000000    5.100000    3.294512    1.701565    1.487978
# 50%     20.000000   11.300000    8.073016    2.238918    2.006065
# 75%     30.000000   20.146341   18.925000    2.717430    2.664847
# max    400.000000  235.200000  148.400000    6.172756    5.294334

# %%
df.plot.scatter(x="T3",y="T4")
#from plot below by inspection a linear relationship between T3 and T4 can be seen#
#T3=T4 is the best fit line from the plot above by inspection
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='T3', ylabel='T4'>

# %%
df.plot.scatter(x="T3adjusted",y="T4adjusted")
#the plot of T3adjusted against T4adjusted normalises the data
#the linearity between T3adjusted and T4adjusted remains with T3adjusted=T4adjusted as the best fit line
# Out:
# <Axes: xlabel='T3adjusted', ylabel='T4adjusted'>

# %%
obj=cl.Data_Cleaning(df)#initialising the object of the class

# %%
cl?

# %%
obj.df
# Out:
#      Level    T4    T3  T3adjusted  T4adjusted
# 0        5   8.1   2.1    2.008299    1.280579
# 1        5   8.7   NaN    2.056710         NaN
# 2       10   3.5   1.6    1.518294    1.169607
# 3       20   7.9   4.6    1.991632    1.663103
# 4       30   2.3   0.4    1.320006    0.736806
# ..     ...   ...   ...         ...         ...
# 494    150 -13.6  -4.5   -2.386966   -1.650964
# 495     60  17.2  29.2    2.581326    3.079363
# 496    400   2.7  14.7    1.392477    2.449660
# 497    150  29.4  27.6    3.086378    3.022060
# 498    200   6.5   3.8    1.866256    1.560491
#
# [499 rows x 5 columns]

# %%
df=obj.missing_values()#replace any missing values with average for their level.
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.describe()
# Out:
#             Level          T4          T3  T3adjusted  T4adjusted
# count  499.000000  499.000000  499.000000  499.000000  499.000000
# mean    35.861723   15.631516   12.941663    2.037433    1.884608
# std     64.513618   19.584716   14.774768    1.286880    1.121725
# min      5.000000  -44.400000  -38.400000   -3.541014   -3.373731
# 25%     10.000000    5.289344    3.992598    1.709976    1.502918
# 50%     20.000000   11.600000    9.000000    2.223980    1.948998
# 75%     30.000000   19.933333   16.992029    2.705339    2.495517
# max    400.000000  235.200000  148.400000    6.172756    5.294334

# %%
df=obj.removing_rows()#exclude values that have T4/T3>3 or T3/T4>3 to remove extreme outliers

# %%
df.describe()
# Out:
#             Level          T4          T3  T3adjusted  T4adjusted
# count  406.000000  406.000000  406.000000  406.000000  406.000000
# mean    34.273399   15.085603   14.146455    2.184555    2.039749
# std     57.642162   12.850178   15.181063    1.023600    1.030806
# min      5.000000  -44.400000  -38.400000   -3.541014   -3.373731
# 25%     10.000000    6.629913    4.734146    1.875777    1.675431
# 50%     20.000000   12.400000   10.800000    2.289428    2.080084
# 75%     30.000000   20.486585   19.097223    2.720124    2.610999
# max    400.000000   74.900000  148.400000    4.215288    5.294334

# %%
df.plot.scatter(x="T3adjusted",y="T4adjusted")
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='T3adjusted', ylabel='T4adjusted'>

# %%
df.plot.scatter(x="T3",y="T4")#data quality has improved for T4 against T3 and the adjusted data
# Out:
# <Axes: xlabel='T3', ylabel='T4'>

# %%
table=obj.table_statistics()

# %%
table
# Out:
#             Level          T4          T3  T3adjusted  T4adjusted
# count  406.000000  406.000000  406.000000  406.000000  406.000000
# mean    34.273399   15.085603   14.146455    2.184555    2.039749
# std     57.642162   12.850178   15.181063    1.023600    1.030806
# min      5.000000  -44.400000  -38.400000   -3.541014   -3.373731
# 25%     10.000000    6.695652    4.800000    1.875777    1.676516
# 50%     20.000000   12.450000   10.900000    2.292599    2.080084
# 75%     30.000000   20.733333   19.097223    2.741295    2.610999
# max    400.000000   74.900000  148.400000    4.215288    5.294334

# %%
df.describe()#for 25%,50% and 75% values are very close but not identical, the rest are identical
# Out:
#             Level          T4          T3  T3adjusted  T4adjusted
# count  406.000000  406.000000  406.000000  406.000000  406.000000
# mean    34.273399   15.085603   14.146455    2.184555    2.039749
# std     57.642162   12.850178   15.181063    1.023600    1.030806
# min      5.000000  -44.400000  -38.400000   -3.541014   -3.373731
# 25%     10.000000    6.629913    4.734146    1.875777    1.675431
# 50%     20.000000   12.400000   10.800000    2.289428    2.080084
# 75%     30.000000   20.486585   19.097223    2.720124    2.610999
# max    400.000000   74.900000  148.400000    4.215288    5.294334

# %%
array=obj.repeated_rows()#array with repeated rows

# %%
array
# Out:
# [[17, 393],
#  [50, 394],
#  [66, 303],
#  [74, 308],
#  [77, 395],
#  [79, 254],
#  [98, 396],
#  [99, 397],
#  [122, 398],
#  [132, 399],
#  [136, 233],
#  [180, 400],
#  [192, 401],
#  [199, 403],
#  [215, 404],
#  [221, 405]]

# %%
df.iloc[17]#checking that they are indeed duplicates
# Out:
# Level         200.000000
# T4             12.000000
# T3             15.785714
# T3adjusted      2.289428
# T4adjusted      2.305618
# Name: 22, dtype: float64

# %%
df.iloc[393]
# Out:
# Level         200.000000
# T4             12.000000
# T3             15.785714
# T3adjusted      2.289428
# T4adjusted      2.305618
# Name: 483, dtype: float64

# %% [markdown]
# ## Task 2

# %%
#matrix multiplication investigation

process = psutil.Process(os.getpid())
baseRam = process.memory_info().rss

resTime = np.zeros(10)
resSpace = np.zeros(10)

for i in range(1,11):
    gc.collect()
    start = time.time()
    cl.matrix_multiplication(i*1000)
    end = time.time()
    ram = process.memory_info().rss    
    resTime[i-1] = end - start
    resSpace[i-1] = ram - baseRam

# %%
size=np.linspace(1000,10000,10)

# %%
data=np.asarray([size,resTime,resSpace]).T
columns=['Size','Time','Space']

# %%
lf=pd.DataFrame(data=data,columns=columns)

# %%
lf.plot(x='Size',y='Time',title='Time against Size')#parabolic increase in time is seen below
# Out:
# <Axes: title={'center': 'Time against Size'}, xlabel='Size'>

# %%
lf.plot(x='Size',y='Space',title='Space against Size')
#no clear pattern in space used but increase in space is not exponentially increasing with size
#More variables seem to affect the space used that cannot be controlled
# Out:
# <Axes: title={'center': 'Space against Size'}, xlabel='Size'>

# %%
#integer sorting investigation
process = psutil.Process(os.getpid())
baseRam = process.memory_info().rss

resTime = np.zeros(10)
resSpace = np.zeros(10)

for i in range(1,11):
    gc.collect()
    start = time.time()
    cl.int_sorting(i*1000)
    end = time.time()
    ram = process.memory_info().rss    
    resTime[i-1] = end - start
    resSpace[i-1] = ram - baseRam

# %%
size=np.linspace(1000,10000,10)
data=np.asarray([size,resTime,resSpace]).T
columns=['Size','Time','Space']
lf=pd.DataFrame(data=data,columns=columns)

# %%
lf.plot(x='Size',y='Time',title='Time against Size')#parabolic increase in time is seen below
# Out:
# <Axes: title={'center': 'Time against Size'}, xlabel='Size'>

# %%
lf.plot(x='Size',y='Space',title='Space against Size')
#no clear pattern in space used but increase in space is not exponentially increasing with size
#More variables seem to affect the space used that cannot be controlled
# Out:
# <Axes: title={'center': 'Space against Size'}, xlabel='Size'>

# %%
#testing that the subset_string function works
string='I am Stelios'
substring='am'
cl.subset_string(string,substring)
# Out:
# 'There is a match at index 2'

# %%
#substring loop-based implementation

process = psutil.Process(os.getpid())
baseRam = process.memory_info().rss

resTime = np.zeros(10)
resSpace = np.zeros(10)

string='abcdefghijklmnopqrstuvwxyz'

for i in range(1,11):
    gc.collect()
    start = time.time()
    txt="".join(string[np.random.randint(0,26, (i*1000))[j]] for j in range(i*1000))
    lookup="".join(string[np.random.randint(0,26, (10))[j]] for j in range(10))
    cl.subset_string(txt,lookup)
    end = time.time()
    ram = process.memory_info().rss    
    resTime[i-1] = end - start
    resSpace[i-1] = ram - baseRam

# %%
#implementation with python function


process = psutil.Process(os.getpid())
baseRam = process.memory_info().rss

resTime_python = np.zeros(10)
resSpace_python = np.zeros(10)

for i in range(1,11):
    gc.collect()
    start = time.time()
    txt="".join(string[np.random.randint(0,26, (i*1000))[j]] for j in range(i*1000))
    lookup="".join(string[np.random.randint(0,26, (10))[j]] for j in range(10))
    x=txt.find(lookup)
    end = time.time()
    ram = process.memory_info().rss    
    resTime_python[i-1] = end - start
    resSpace_python[i-1] = ram - baseRam

# %%
size=np.linspace(1000,10000,10)
data=np.asarray([size,resTime,resTime_python,resSpace,resSpace_python]).T
columns=['Size','Time with loop','Time with Python','Space with loop','Space with python']
lf=pd.DataFrame(data=data,columns=columns)

# %%
lf.plot(x='Size',y=['Time with loop','Time with Python'])
#parabolic increase in time against size is seen below with almost identical performance for both
# Out:
# <Axes: xlabel='Size'>

# %%
lf.plot(x='Size',y=['Space with loop','Space with python'])
#performance can vary when run at different times between 2 methods
#In the case shown below space with python remains constant at the most part after size=3000, similar pattern for space with loop 
#python performs much better in space used
#More variables seem to affect the space used that cannot be controlled
# Out:
# <Axes: xlabel='Size'>
